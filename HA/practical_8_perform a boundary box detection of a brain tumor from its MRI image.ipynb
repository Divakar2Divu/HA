# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import files
print("Upload your YOLOv8 model file (e.g., best.pt)")
uploaded_model = files.upload()
# Out:
# Upload your YOLOv8 model file (e.g., best.pt)
#      <input type="file" id="files-6c1503fe-1f8a-4340-b247-aebddde672ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c1503fe-1f8a-4340-b247-aebddde672ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
uploaded_test_images = files.upload()
# Out:
#      <input type="file" id="files-b8142ff2-849b-4dd0-9758-8c59acf2f3b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8142ff2-849b-4dd0-9758-8c59acf2f3b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("/content/yolov8n.pt")

# %%
results = model.predict(source="test_images", save=True, conf=0.25)
# Out:
# image 1/39 /content/test_images/00306_109_jpg.rf.14014c8a4460a1f21b7f24d6b0c3fd7a.jpg: 640x480 (no detections), 380.5ms
# image 2/39 /content/test_images/00306_115_jpg.rf.91c4f9cd703fec2885778c34c52bd34a.jpg: 640x480 1 vase, 163.8ms
# image 3/39 /content/test_images/00306_92_jpg.rf.f6f1a5697229fd7dcb5a8a9c44cfb7e0.jpg: 640x480 1 teddy bear, 147.1ms
# image 4/39 /content/test_images/00306_96_jpg.rf.c38afdeeadaf853872e03d0dea4d3489.jpg: 640x480 1 vase, 1 teddy bear, 119.1ms
# image 5/39 /content/test_images/00311_105_jpg.rf.a28be74fddf1573f17e09336d6832db0.jpg: 640x480 (no detections), 116.3ms
# image 6/39 /content/test_images/00311_111_jpg.rf.18b1b047eabca14e304fe6a05961a074.jpg: 640x480 (no detections), 115.5ms
# image 7/39 /content/test_images/00311_117_jpg.rf.06054524a0378e24b3be9886aef9ea62.jpg: 640x480 (no detections), 111.1ms
# image 8/39 /content/test_images/00311_118_jpg.rf.57b5f9460bdfb33ce4acfc3410200f7f.jpg: 640x480 (no detections), 112.3ms
# ...

# %%
import glob
from PIL import Image as PILImage

# %%
output_dir = "runs/detect/predict"
output_images = glob.glob(f"{output_dir}/*.jpg")

# %%
print(f"Predicted {len(output_images)} image(s). Displaying them...")

for image_path in output_images:
    display(PILImage.open(image_path))
# Out:
# Predicted 39 image(s). Displaying them...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
# ...
